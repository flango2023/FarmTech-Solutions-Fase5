# %% [markdown]
# # FarmTech Solutions - Fase 5 (Google Colab)
#
# Este notebook foi preparado para rodar diretamente no **Google Colab**.
# Siga os passos abaixo e execute as células em ordem.

# %% [markdown]
# ## 1) Instalar dependências
#
# As dependências estão listadas em `requirements.txt`.
# Se você sofreu algum erro de versão, atualize aqui antes de executar novamente.

# %%
# Instala dependências necessárias
# !pip install -q -r requirements.txt

# %% [markdown]
# ## 2) Carregar dados e executar notebook principal
#
# Este notebook assume que o arquivo `crop_yield.csv` está na mesma pasta.
# Se você tiver clonado o repositório diretamente no Colab, ele já estará disponível.

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('crop_yield.csv')
print('Dataset carregado com sucesso!')
print('Dimensões:', df.shape)
df.head()

# %% [markdown]
# ## 3) Executar análise completa
#
# As próximas etapas (EDA, clustering, outliers e modelagem) estão no notebook principal:
# `RichardSchmitz_rm567951_pbl_fase5.ipynb`
#
# Se preferir, abra o notebook principal no Colab e execute todas as células em ordem.
